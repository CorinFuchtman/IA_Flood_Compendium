# %%
# !pip install matplotlib seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.10.9)
# Requirement already satisfied: seaborn in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: tzdata in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\cfuchtman\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
df = pd.read_csv('StormEvents_2024.csv')
stormEvents = DataFrame(df)
print(stormEvents)
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0               202404         30        2033         202404       30
# 1               202407          1           0         202407        5
# 2               202411         16         230         202411       18
# 3               202405         22        1230         202405       22
# 4               202405         21        1200         202405       21
# ...                ...        ...         ...            ...      ...
# 69796           202406         18        1823         202406       18
# 69797           202406         26        1918         202406       26
# 69798           202406         26        1919         202406       26
# 69799           202406         26        1930         202406       26
# 69800           202406         26        1918         202406       26
#
#        END_TIME  EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  \
# 0          2033      189851   1174463      OKLAHOMA          40  ...
# 1           900      193486   1195301     LOUISIANA          22  ...
# 2          1421      197838   1223377        OREGON          41  ...
# 3          1615      191723   1184135         TEXAS          48  ...
# 4          1530      191723   1184133         TEXAS          48  ...
# ...         ...         ...       ...           ...         ...  ...
# 69796      1823      193858   1197757  PENNSYLVANIA          42  ...
# 69797      1918      193907   1198089  PENNSYLVANIA          42  ...
# 69798      2030      193907   1198092  PENNSYLVANIA          42  ...
# 69799      2030      193907   1198098  PENNSYLVANIA          42  ...
# 69800      2030      193907   1198091  PENNSYLVANIA          42  ...
#
#        END_RANGE END_AZIMUTH    END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT  \
# 0           0.42         SSW  FREDERICK ARPT   34.3444   -98.9830  34.3444
# 1            NaN         NaN             NaN       NaN        NaN      NaN
# 2            NaN         NaN             NaN       NaN        NaN      NaN
# 3            NaN         NaN             NaN       NaN        NaN      NaN
# 4            NaN         NaN             NaN       NaN        NaN      NaN
# ...          ...         ...             ...       ...        ...      ...
# 69796       1.00           N    KELLETTVILLE   41.5700   -79.2700  41.5700
# 69797       1.00           N      HANNASTOWN   40.3700   -79.5000  40.3700
# 69798       1.00         WNW        CRABTREE   40.3800   -79.4900  40.3800
# 69799       0.00         SSE         OAKMONT   40.5171   -79.8231  40.5158
# 69800       1.00         ESE   MC KEES ROCKS   40.4652   -80.0542  40.4646
#
#        END_LON                                  EPISODE_NARRATIVE  \
# 0     -98.9830  A rather nebulous upper air pattern existed ac...
# 1          NaN  An upper ridge of high pressure built in acros...
# 2          NaN  A series of cold fronts the weekend of Nov. 16...
# 3          NaN  A strong upper-level subtropical ridge/heat do...
# 4          NaN  A strong upper-level subtropical ridge/heat do...
# ...        ...                                                ...
# 69796 -79.2700  Despite an amplifying strong eastern CONUS the...
# 69797 -79.5000  A well-organized upper shortwave trough crossi...
# 69798 -79.4900  A well-organized upper shortwave trough crossi...
# 69799 -79.8286  A well-organized upper shortwave trough crossi...
# 69800 -80.0590  A well-organized upper shortwave trough crossi...
#
#                                          EVENT_NARRATIVE DATA_SOURCE
# 0        Frederick Municipal Airport (KFDR) observation.         CSV
# 1                                                    NaN         CSV
# 2      The Hog Pass SNOTEL reported an estimated 12 i...         CSV
# 3      Harlingen Valley International Airport (KHRL) ...         CSV
# 4      By proxy, between locations in northern Kenedy...         CSV
# ...                                                  ...         ...
# 69796                    Trees down along Balltown road.         CSV
# 69797                            Several trees uprooted.         CSV
# 69798                          Thunderstorm wind damage.         CSV
# 69799                Flooding reported along Commons Dr.         CSV
# 69800             Flooding reported near Roxian Theatre.         CSV
#
# [69801 rows x 51 columns]

# %%
iowaStorms = stormEvents.drop(stormEvents[stormEvents['STATE'] != 'IOWA'].index)
iowaFloods = iowaStorms.drop(iowaStorms[iowaStorms['EVENT_TYPE'] != 'Flood'].index)
iowaFlashFloods = iowaStorms.drop(iowaStorms[iowaStorms['EVENT_TYPE'] != 'Flash Flood'].index)
iowaFloods.dropna(how='all', axis=1, inplace=True)
iowaFlashFloods.dropna(how='all', axis=1, inplace=True)
print(iowaFloods)
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 19802           202404         30        2100         202404       30
# 20962           202405         22         230         202405       23
# 21160           202405         24         600         202405       24
# 21161           202405         24        1945         202405       25
# 21163           202405         22         430         202405       24
# ...                ...        ...         ...            ...      ...
# 44509           202406         21         400         202406       30
# 44521           202406         17        1900         202406       30
# 45054           202406         24        1609         202406       30
# 47143           202406         24           0         202406       30
# 62981           202407          1           0         202407        4
#
#        END_TIME  EPISODE_ID  EVENT_ID STATE  STATE_FIPS  ...  END_RANGE  \
# 19802      2359      189673   1166183  IOWA          19  ...       1.71
# 20962      1715      192209   1185183  IOWA          19  ...       2.14
# 21160      1230      192209   1185184  IOWA          19  ...       2.14
# 21161      2345      192209   1185186  IOWA          19  ...       5.51
# 21163      2330      192209   1185610  IOWA          19  ...       2.07
# ...         ...         ...       ...   ...         ...  ...        ...
# 44509      2359      191899   1195673  IOWA          19  ...       5.76
# 44521      2359      192821   1190188  IOWA          19  ...       3.02
# 45054      2359      193922   1198873  IOWA          19  ...       0.86
# 47143      2359      193922   1198875  IOWA          19  ...       5.96
# 62981       400      194192   1199942  IOWA          19  ...       2.10
#
#       END_AZIMUTH        END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT  END_LON  \
# 19802         WSW             DICKENS    43.150   -95.1800  43.1000 -95.1000
# 20962           S          DES MOINES    41.570   -93.6100  41.5900 -93.6200
# 21160           S          DES MOINES    41.570   -93.6100  41.5900 -93.6200
# 21161          SE         WELLINGFORD    43.260   -94.8300  43.2600 -94.7100
# 21163         WSW          DES MOINES    41.590   -93.5600  41.5900 -93.6600
# ...           ...                 ...       ...        ...      ...      ...
# 44509         ENE          SUTHERLAND    43.010   -95.4400  42.9900 -95.4500
# 44521          SW             SPENCER    43.130   -95.2900  43.1100 -95.2000
# 45054         WNW              GRABLE    41.510   -95.8900  41.5100 -96.0200
# 47143         WNW  HAMBURG REIDS ARPT    40.586   -95.8156  40.5857 -95.6779
# 62981          NW             GRANITE    43.500   -96.5986  43.4825 -96.5849
#
#                                        EPISODE_NARRATIVE  \
# 19802  A wet last week of April resulted in saturated...
# 20962  There were several rounds of rainfall over the...
# 21160  There were several rounds of rainfall over the...
# 21161  There were several rounds of rainfall over the...
# 21163  There were several rounds of rainfall over the...
# ...                                                  ...
# 44509  A multi-day significant heavy rainfall event f...
# 44521  A wet period allowed for flooding to return to...
# 45054  A series of shortwave troughs traversing the n...
# 47143  A series of shortwave troughs traversing the n...
# 62981  River levels from the historic June flooding r...
#
#                                          EVENT_NARRATIVE DATA_SOURCE
# 19802  The Little Sioux River at Spencer, IA rose abo...         CSV
# 20962  The Raccoon River at Fleur Drive crested at 14...         CSV
# 21160  The Raccoon River at Fleur Drive crested at 12...         CSV
# 21161  The West Fork Des Moines River at Estherville ...         CSV
# 21163  The Des Moines River at Southeast 6th St crest...         CSV
# ...                                                  ...         ...
# 44509  Waterman Creek near Sutherland rose above floo...         CSV
# 44521  The Ocheyedan River near Spencer rose above fl...         CSV
# 45054  Excessive rainfall across much of eastern Sout...         CSV
# 47143  Excessive rainfall across much of eastern Sout...         CSV
# 62981  Flooding continued from June on the Big Sioux ...         CSV
#
# [185 rows x 41 columns]

# %%
plt.bar(iowaFloods['CZ_NAME'], iowaFloods['DAMAGE_PROPERTY'])
plt.xlabel('County')
plt.ylabel('Property Damage ($)')
plt.title('Property Damage from Floods in Iowa (2024)')
plt.show()

# %%
plot = sns.barplot(data=iowaFloods, x='CZ_NAME', y='DAMAGE_PROPERTY') 
plot.set_title('Property Damage from Floods in Iowa (2024)')
plt.show()

# %%
def newDate():
    year_month = iowaFloods['BEGIN_YEARMONTH'].astype(str)
    day = iowaFloods['BEGIN_DAY'].astype(str)
    if len(day) ==1:
        day = '0' + day
    date = year_month + day
    iowaFloods['DATE'] = date
    iowaFloods.sort_values(by='DATE', inplace=True)
newDate()

# %%
iowaFloods['COUNT'] = range(1, len(iowaFloods) + 1)

# %%
plt.plot(iowaFloods['DATE'], iowaFloods['COUNT'])
plt.xlabel('Date')
plt.ylabel('Number of Floods')
plt.title('Number of Floods in Iowa (2024)')
plt.show()
