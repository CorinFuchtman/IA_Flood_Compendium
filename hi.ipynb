# %%
# !pip install --upgrade pip
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------- ----- 1.6/1.8 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 12.5 MB/s  0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 26.1.1
#     Uninstalling pip-26.1.1:
#       Successfully uninstalled pip-26.1.1
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd

from pandas import DataFrame

# %%
import csv

# %%
with open('IAfloodsNOAA.csv', 'r') as file:
    df = pd.read_csv('IAfloodsNOAA.csv')

# %%
floodData = DataFrame(df)
print(floodData)
# Out:
#      EVENT_ID     CZ_NAME_STR BEGIN_LOCATION BEGIN_DATE  BEGIN_TIME  \
# 0     5540507     POLK (ZONE)                  2/9/1996         600
# 1     5540510   MARION (ZONE)                  2/9/1996         600
# 2     5540511  MAHASKA (ZONE)                  2/9/1996         600
# 3     5540506   DALLAS (ZONE)                  2/9/1996         600
# 4     5540508   JASPER (ZONE)                  2/9/1996         600
# ..        ...             ...            ...        ...         ...
# 495   5653150    STORY (ZONE)                 6/14/1998         900
# 496   5653143  GUTHRIE (ZONE)                 6/14/1998         900
# 497   5653151     TAMA (ZONE)                 6/14/1998         900
# 498   5653135   HARDIN (ZONE)                 6/14/1998         900
# 499   5653138  CARROLL (ZONE)                 6/14/1998         900
#
#     EVENT_TYPE MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  INJURIES_DIRECT  ...  \
# 0        Flood                                    0                0  ...
# ...

# %%
table.describe()
# Out:
#            EVENT_ID   BEGIN_TIME  DEATHS_DIRECT  INJURIES_DIRECT  \
# count  5.000000e+02   500.000000     500.000000            500.0
# mean   5.587077e+06  1126.296000       0.002000              0.0
# std    3.603046e+04   671.127735       0.044721              0.0
# min    5.540501e+06     0.000000       0.000000              0.0
# 25%    5.553668e+06   600.000000       0.000000              0.0
# 50%    5.589264e+06  1200.000000       0.000000              0.0
# 75%    5.605553e+06  1800.000000       0.000000              0.0
# max    5.663182e+06  2337.000000       1.000000              0.0
#
#        DAMAGE_PROPERTY_NUM  DAMAGE_CROPS_NUM    EPISODE_ID     CZ_FIPS  \
# count         5.000000e+02      5.000000e+02  5.000000e+02  500.000000
# mean          9.015700e+04      1.995520e+05  1.974034e+06   67.268000
# std           6.279960e+05      2.002036e+06  2.953945e+05   41.021185
# min           0.000000e+00      0.000000e+00  1.005160e+06    1.000000
# ...

# %%
df = pd.read_csv('IAfloodsNOAA.csv')

counts = df['EVENT_TYPE'].value_counts()

numFlood = counts.get("Flood", 0)
numFlash = counts.get("Flash Flood", 0)

print((numFlood, numFlash))
# Out:
# (np.int64(444), np.int64(56))
